# %% [markdown]
# <a href="https://colab.research.google.com/github/buri0lla/programacao/blob/main/Li%C3%A7%C3%A3o%20aula%20online.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada
numero1 = float (input( ))
numero2 = float (input( ))
numero3 = float (input( ))

#processamento
media = (numero1 + numero2 + numero3) / 3

#saída
print (f"{media}")
# Out:
# 0
# 0
# 0
# 0.0

# %%
# entrada
celsius = float (input( ))
#processmento

fahrenheit = (celsius * 9 / 5) + 32
#saída
print (f"{fahrenheit}")
# Out:
# 35
# 95.0

# %%
#entrada
combustivel = float(input())
quilometro = float(input())
#processamento
lkm = combustivel / quilometro
#saída
print(f"o combustivel médio gasto foi {lkm}")
# Out:
# 8
