# %% [markdown]
# <a href="https://colab.research.google.com/github/buri0lla/programacao/blob/main/C%C3%B3pia_de_aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *aula de programação e algoritmo:*
#  calcular a área de uma sala
#  *entrada *
#  medir o cumprimento da sala
#  medir a largura da sala
#  *processamento*
#  fazer a multiplicação do cumprimento pela largura
#  *saída*
#  mostrar o resultado

# %% [markdown]
# **atividade:**
# escrever um algoritmo e depois o programa que recebe um número e calcula do dobro do número

# %%
# entrada
import random
numero = random.randint (1, 100)
# processamento
resultado = numero * 2
#saída
print (f"o resultado é: {resultado}")
# Out:
# o resultado é: 72

# %%
# entrada
import random
numero1 = random.randint (1, 100)
numero2 = random.randint (1, 100)
numero3 = random.randint (1, 100)
numero4 = random.randint (1, 100)
# processamento
resultado = (numero1 + numero2 + numero3 + numero4) /4
#saída
print (f"o resultado é: {resultado}")
# Out:
# o resultado é: 46.0
