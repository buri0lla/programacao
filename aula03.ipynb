# %% [markdown]
# <a href="https://colab.research.google.com/github/buri0lla/programacao/blob/main/aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *aula de programação e algoritmo:*
#  calcular a área de uma sala
#  *entrada *
#  medir o cumprimento da sala
#  medir a largura da sala
#  *processamento*
#  fazer a multiplicação do cumprimento pela largura
#  *saída*
#  mostrar o resultado

# %%
#entrada

cumprimento = 7 # metros
largura = 4 # metros

# %%
#processamneto

area = cumprimento * largura

# %%
#saída
print (f" area total da sala é: {area} metros quadrados")
# Out:
#  area total da sala é: 28 metros quadrados

# %%
#entrada
lado = 2
#processamento
resultado = lado * lado
#saída
print (f" o quadrado é: {resultado}")
# Out:
#  o quadrado é: 4

# %% [markdown]
# **atividade:**
# escrever um algoritmo e depois o programa que recebe um número e calcula do dobro do número

# %%
# entrada
import random
numero = random.randint (1, 100)
# processamento
resultado = numero * 2
#saída
print (f"o resultado é: {resultado}")
# Out:
# o resultado é: 8

# %%
# entrada
import random
numero1 = random.randint (1, 100)
import random
numero2 = random.randint (1, 100)
import random
numero3 = random.randint (1, 100)
import random
numero4 = random.randint (1, 100)
soma = +
subtração = -
multiplicação = *
divisão = /
# processamento
resultado = soma (numero1),(numero2)
#saída
print (f"o resultado é: {resultado}")
# Out:
#   File "/tmp/ipykernel_445/2760995978.py", line 10
#     soma = +
#             ^
# SyntaxError: invalid syntax
